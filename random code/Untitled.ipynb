# %%
import pandas as pd

# %%
file1_path = "data/processed_data.csv"  # Replace with your actual file path
df1 = pd.read_csv(file1_path)

# Load the second dataset
file2_path = "data/processed_trade_data.csv"  # Replace with your actual file path
df2 = pd.read_csv(file2_path)

# Inspect the columns of both datasets
print("Columns in the first dataset:")
print(df1.columns)

print("\nColumns in the second dataset:")
print(df2.columns)
# Out:
# Columns in the first dataset:
# Index(['Survey's country', 'Alcoholic beverages',
#        'Amphibians, reptiles, and terrestrial invertebrates',
#        'Animal and vegetable fats and oils and primary derivatives thereof',
#        'Coffee, cocoa, tea and infusions', 'Composite dishes',
#        'Eggs and egg products', 'Fish and seafood',
#        'Food products for young population', 'Fruit and fruit products',
#        'Fruit and vegetable juices and nectars (including concentrates)',
#        'Grains and grain-based products', 'Legumes, nuts, oilseeds and spices',
#        'Major isolated ingredients, additives, flavours, baking and processing aids',
#        'Meat and meat products', 'Milk and dairy products',
#        'Products for non-standard diets, food imitates and food supplements',
#        'Seasoning, sauces and condiments',
#        'Starchy roots or tubers and products thereof, sugar plants',
# ...

# %%
df2
# Out:
#         Item                                         Unnamed: 1  \
# 0    Element                                                NaN
# 1       Year                                               Area
# 2       2000                                            Albania
# 3       2000                                            Austria
# 4       2000                                            Belarus
# ..       ...                                                ...
# 951     2023                                              Spain
# 952     2023                                             Sweden
# 953     2023                                        Switzerland
# 954     2023                                            Ukraine
# 955     2023  United Kingdom of Great Britain and Northern I...
#
#     Alcoholic Beverages Alcoholic Beverages.1 Alcoholic Beverages.2  \
# 0       Export quantity          Export value       Import quantity
# ...

# %%
# Filter specific columns from the second dataset
filtered_df = df2[['Fruit and Vegetables', 'Fruit and Vegetables.1']]

# Display the filtered DataFrame
filtered_df
# Out:
#     Fruit and Vegetables Fruit and Vegetables.1
# 0           Export value           Import value
# 1                    NaN                    NaN
# 2                 2003.0                43129.0
# 3              511125.02             1019300.97
# 4               52702.69               97138.18
# ..                   ...                    ...
# 951           24964420.9             8994302.49
# 952            458037.39             2940503.45
# 953            103774.05             3192976.59
# 954            570759.38             1423265.03
# 955           1200950.52            16556890.33
#
# [956 rows x 2 columns]

# %%
# Specify the columns you want to filter
columns_to_filter = [
    'Cereal preparations total', 'Cereal preparations total.1',
    'Cereal preparations total.2', 'Cereal preparations total.3',
    'Cereals', 'Cereals.1', 'Cereals.2', 'Cereals.3',
    'Cereals and Preparations', 'Cereals and Preparations.1'
]

# Filter the specified columns from the second dataset
filtered_df = df2[columns_to_filter]

# Display the filtered DataFrame
filtered_df
# Out:
#     Cereal preparations total Cereal preparations total.1  \
# 0             Export quantity                Export value
# 1                         NaN                         NaN
# 2                       200.0                       292.0
# 3                    170497.0                    221194.6
# 4                    75176.19                     22810.2
# ..                        ...                         ...
# 951                1700421.69                  3484799.65
# 952                 406916.17                   966388.63
# 953                  173236.1                   886198.19
# 954                 399500.19                   381923.26
# 955                1101797.95                  3059537.98
#
#     Cereal preparations total.2 Cereal preparations total.3          Cereals  \
# 0               Import quantity                Import value  Export quantity
# 1                           NaN                         NaN              NaN
# ...

# %%
# Display all column names in the DataFrame
print(df_pivot_trade.columns.tolist(

    # Define the categories to drop
categories_to_drop = ['Dairy Products and Eggs', 'Cereals and Preparations', 'Fruit and Vegetables']

# Filter out the columns where the first level matches any of the specified categories
df_pivot_trade = df_pivot_trade[[col for col in df_pivot_trade.columns if col[0] not in categories_to_drop]]

# Display the updated DataFrame
df_pivot_trade.head()
