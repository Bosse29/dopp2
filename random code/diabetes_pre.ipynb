# %%
import pandas as pd
import os

# %%
file_path = "raw/Diabetes/diabetes_raw.csv"  # Replace with your file's location
df_diabetes = pd.read_csv(file_path)

# Keep only the columns for 'Country/Territory', '2011', and '2021'
df_cleaned = df_diabetes[['Country/Territory', '2011', '2021']]

# Save the cleaned data to a new CSV file
output_file = "data/diabetes_cleaned.csv"  # Replace with your desired output location
df_cleaned.to_csv(output_file, index=False)

# %%
df_cleaned
# Out:
#          Country/Territory 2011  2021
# 0                   Turkey  7.9  14.5
# 1                    Spain  6.3  10.3
# 2                  Albania  2.8  10.2
# 3                  Andorra  5.4   9.7
# 4   Bosnia and Herzegovina  7.5   9.1
# 5               Montenegro  7.7   9.1
# 6                 Portugal  9.6   9.1
# 7                   Serbia  7.7   9.1
# 8                   Cyprus  9.3   8.6
# 9                   Israel  7.4   8.5
# 10                   Malta  6.6   8.0
# 11                Bulgaria  6.7   7.4
# 12              San Marino  5.5   7.4
# 13                Holy See    -   7.3
# 14                 Czechia  5.3   7.1
# 15                  Europe  6.7   7.0
# 16                 Hungary  6.0   7.0
# 17              Uzbekistan  6.4   7.0
# 18                 Germany  5.3   6.9
# 19                  Poland  9.0   6.8
# 20            Turkmenistan  2.7   6.7
# 21              Kazakhstan  7.7   6.6
# 22              Kyrgyzstan  6.3   6.6
# 23              Tajikistan  6.3   6.6
# 24                 Estonia  7.0   6.5
# 25                 Romania  7.7   6.5
# 26                  Greece  5.1   6.4
# 27                   Italy  5.1   6.4
# 28         Channel Islands  4.9   6.3
# 29             Isle of Man    -   6.3
# 30          United Kingdom  5.2   6.3
# 31                  Monaco  5.6   6.2
# 32                 Finland  5.8   6.1
# 33           Liechtenstein  4.7   6.1
# 34         North Macedonia  7.7   6.1
# 35                  Latvia  7.8   5.9
# 36              Luxembourg  4.5   5.9
# 37               Lithuania  7.8   5.8
# 38                Slovakia  5.7   5.8
# 39                Slovenia  7.5   5.8
# 40                 Georgia  2.8   5.7
# 41                 Armenia  8.5   5.6
# 42              Azerbaijan  2.8   5.6
# 43                 Belarus  8.0   5.6
# 44     Republic of Moldova  2.7   5.6
# 45      Russian Federation  9.7   5.6
# 46                 Ukraine  2.9   5.6
# 47                 Iceland  3.2   5.5
# 48                 Denmark  5.6   5.3
# 49                  France  5.4   5.3
# 50                  Sweden  4.2   5.0
# 51                 Croatia  5.2   4.8
# 52                 Austria  6.6   4.6
# 53             Switzerland  5.9   4.6
# 54             Netherlands  5.3   4.5
# 55           Faroe Islands    -   3.8
# 56                 Belgium  4.8   3.6
# 57                  Norway  4.7   3.6
# 58               Greenland    -   3.3
# 59                 Ireland  5.2   3.0
